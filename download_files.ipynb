# %%
# !wget --no-parent http://178.62.224.64/~bondy/Python_Intro.tar
# !tar -xvf Python_Intro.tar
# Out:
# --2018-06-01 12:50:46--  http://178.62.224.64/~bondy/Python_Intro.tar
# Connecting to 178.62.224.64:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92160 (90K) [application/x-tar]
# Saving to: ‘Python_Intro.tar’
#
# Python_Intro.tar    100%[===================>]  90.00K  --.-KB/s    in 0s
#
# 2018-06-01 12:50:46 (229 MB/s) - ‘Python_Intro.tar’ saved [92160/92160]
#
# Python_Introduction/
# Python_Introduction/1-Basics_of_Python.ipynb
# Python_Introduction/README.md
# Python_Introduction/LICENSE
# Python_Introduction/myhelpers.py
# Python_Introduction/2-Basics_of_Python_2.ipynb
# Python_Introduction/16tstcar.csv
# Python_Introduction/31380.css
# Python_Introduction/3-Modules_Vectors_Plots.ipynb

# %%
# !wget --no-parent http://bit.ly/CEEDistContStudyCase
# !tar -xvf CEEDistContStudyCase
# Out:
# --2018-06-04 12:06:00--  http://bit.ly/CEEDistContStudyCase
# Resolving bit.ly (bit.ly)... 67.199.248.10, 67.199.248.11
# Connecting to bit.ly (bit.ly)|67.199.248.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://178.62.224.64/~bondy/simple_study_case.tar [following]
# --2018-06-04 12:06:00--  http://178.62.224.64/~bondy/simple_study_case.tar
# Connecting to 178.62.224.64:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35194880 (34M) [application/x-tar]
# Saving to: ‘CEEDistContStudyCase.1’
#
# CEEDistContStudyCas 100%[===================>]  33.56M  --.-KB/s    in 0.08s
#
# 2018-06-04 12:06:00 (404 MB/s) - ‘CEEDistContStudyCase.1’ saved [35194880/35194880]
#
# simple_study_case/
# simple_study_case/mosaik_battery.py
# simple_study_case/collector.py
# simple_study_case/Run_Mosaik_Scenario.ipynb
# simple_study_case/mosaik_pv.py
# simple_study_case/signals.h5
# simple_study_case/plot_base_case_results.ipynb
# simple_study_case/datastore
# simple_study_case/my_grid_sim.py
# simple_study_case/util.py
# simple_study_case/mosaik_scenario.py
# simple_study_case/mosaik_grid.py
# simple_study_case/my_batt_sim.py
# simple_study_case/mosaik_control.py
# simple_study_case/mosaik_demand.py

# %%
# !wget --no-parent http://bit.ly/CEEDistContComm
# !tar -xvf CEEDistContComm
# Out:
# --2018-06-07 11:28:44--  http://bit.ly/CEEDistContComm
# Resolving bit.ly (bit.ly)... 67.199.248.10, 67.199.248.11
# Connecting to bit.ly (bit.ly)|67.199.248.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://178.62.224.64/~tue/comm_exercise.tar [following]
# --2018-06-07 11:28:45--  http://178.62.224.64/~tue/comm_exercise.tar
# Connecting to 178.62.224.64:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194560 (190K) [application/x-tar]
# Saving to: ‘CEEDistContComm’
#
# CEEDistContComm     100%[===================>] 190.00K  --.-KB/s    in 0.001s
#
# 2018-06-07 11:28:45 (174 MB/s) - ‘CEEDistContComm’ saved [194560/194560]
#
# comm_exercise/
# comm_exercise/testsyncmaster.sh
# comm_exercise/testpiasyncmaster.sh
# comm_exercise/testbroadcastsender.sh
# comm_exercise/testsyncslave.sh
# comm_exercise/broadcast/
# comm_exercise/broadcast/broadcaster.py
# comm_exercise/broadcast/broadcast_listener.py
# comm_exercise/broadcast/old/
# comm_exercise/broadcast/old/broadcast_receiver.py
# comm_exercise/broadcast/old/broadcast_sender.py
# comm_exercise/.git/
# comm_exercise/.git/index
# comm_exercise/.git/description
# comm_exercise/.git/hooks/
# comm_exercise/.git/hooks/pre-push.sample
# comm_exercise/.git/hooks/update.sample
# comm_exercise/.git/hooks/fsmonitor-watchman.sample
# comm_exercise/.git/hooks/post-update.sample
# comm_exercise/.git/hooks/pre-commit.sample
# comm_exercise/.git/hooks/pre-rebase.sample
# comm_exercise/.git/hooks/applypatch-msg.sample
# comm_exercise/.git/hooks/commit-msg.sample
# comm_exercise/.git/hooks/prepare-commit-msg.sample
# comm_exercise/.git/hooks/pre-applypatch.sample
# comm_exercise/.git/hooks/pre-receive.sample
# comm_exercise/.git/HEAD
# comm_exercise/.git/config
# comm_exercise/.git/ORIG_HEAD
# comm_exercise/.git/FETCH_HEAD
# comm_exercise/.git/branches/
# comm_exercise/.git/objects/
# comm_exercise/.git/objects/ca/
# comm_exercise/.git/objects/ca/407136bf9cecc2a3f23d2b870dc532458e0d05
# comm_exercise/.git/objects/9e/
# comm_exercise/.git/objects/9e/816f7f52b49257536282628b3496f9d4468869
# comm_exercise/.git/objects/1f/
# comm_exercise/.git/objects/1f/1dac4ad9ac92657cb6dc93db5a87b00c09fdd1
# comm_exercise/.git/objects/34/
# comm_exercise/.git/objects/34/bda95d28356dd87d26c5202e9e1526474bcb35
# comm_exercise/.git/objects/c8/
# comm_exercise/.git/objects/c8/c0f8a4a5ddfd108714aa03203ae6e9c4680ed5
# comm_exercise/.git/objects/6f/
# comm_exercise/.git/objects/6f/ebdb51c5b21a71906cf4e89d62e0a21bee6185
# comm_exercise/.git/objects/83/
# comm_exercise/.git/objects/83/a69863e069262fc76ed54c35f4754a21c58923
# comm_exercise/.git/objects/83/3a1cf8ce33e4ed5d763242c5761616fb17cc7b
# comm_exercise/.git/objects/45/
# comm_exercise/.git/objects/45/baba987870abb32125a71ef8fc050690978acc
# comm_exercise/.git/objects/b7/
# comm_exercise/.git/objects/b7/28f35f9b8882f447ac7339ed0ac9b6c6abbbde
# comm_exercise/.git/objects/79/
# comm_exercise/.git/objects/79/ba18614bcf7e1eab7e25c5c2455e81988307c0
# comm_exercise/.git/objects/89/
# comm_exercise/.git/objects/89/348bfffd545facffa58a167b181f96c5a6e5dd
# comm_exercise/.git/objects/ce/
# comm_exercise/.git/objects/ce/10f27e3877ee218383eb8cef0a5475e0309fee
# comm_exercise/.git/objects/bb/
# comm_exercise/.git/objects/bb/e06d8cdd4ea924bb11fcc078bd8648bad338fe
# comm_exercise/.git/objects/3e/
# comm_exercise/.git/objects/3e/bfffc920119e2de0e9d494ae041a012abd4ccc
# comm_exercise/.git/objects/58/
# comm_exercise/.git/objects/58/ec54cd34218a19f949e03cade68fcc17a2c88c
# comm_exercise/.git/objects/d3/
# comm_exercise/.git/objects/cd/
# comm_exercise/.git/objects/cd/50874bf7072ed6407f54a172bad9abf37cc978
# comm_exercise/.git/objects/cd/792613702c03ce58a3c22be70413e97b3b4744
# comm_exercise/.git/objects/2d/
# comm_exercise/.git/objects/2d/17881571c23061208db1dfacd6b774ae37d8f0
# comm_exercise/.git/objects/e6/
# comm_exercise/.git/objects/e6/f1629e65ae7b9d254abb2fbbb8a1ff9dad7df4
# comm_exercise/.git/objects/e6/12cf944eec167b3edb2d8eabeeba5009f1181d
# comm_exercise/.git/objects/e6/9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# comm_exercise/.git/objects/03/
# comm_exercise/.git/objects/03/415510af9123b335b9a8ed7227fa6dce47d6c0
# comm_exercise/.git/objects/3c/
# comm_exercise/.git/objects/3c/54db99ba520175a62b210a1dbe5ba8597153b3
# comm_exercise/.git/objects/14/
# comm_exercise/.git/objects/14/fe895364765f658654ccddef35810f993fdfd3
# comm_exercise/.git/objects/pack/
# comm_exercise/.git/objects/0a/
# comm_exercise/.git/objects/0a/33f5c55c298d041f04a98f436310d01ce203ff
# comm_exercise/.git/objects/6d/
# comm_exercise/.git/objects/6d/07585c4a274e5db58359c67bffd0ab2b8c8995
# comm_exercise/.git/objects/6d/c0159eed2b0e3dee6de6c06c821b3a0358c70c
# comm_exercise/.git/objects/9d/
# comm_exercise/.git/objects/9d/5d2667d3aae0143edd6caeba651dc887fe6660
# comm_exercise/.git/objects/23/
# comm_exercise/.git/objects/23/a9cd0f7241f3e236106391fe057a87151009c2
# comm_exercise/.git/objects/f9/
# comm_exercise/.git/objects/f9/c0216cd7cc5c05670d4ae96765bd21e1997a2e
# comm_exercise/.git/info/
# comm_exercise/.git/info/exclude
# comm_exercise/.git/refs/
# comm_exercise/.git/refs/remotes/
# comm_exercise/.git/refs/remotes/origin/
# comm_exercise/.git/refs/remotes/origin/master
# comm_exercise/.git/refs/heads/
# comm_exercise/.git/refs/heads/master
# comm_exercise/.git/refs/tags/
# comm_exercise/.git/COMMIT_EDITMSG
# comm_exercise/.git/logs/
# comm_exercise/.git/logs/HEAD
# comm_exercise/.git/logs/refs/
# comm_exercise/.git/logs/refs/remotes/
# comm_exercise/.git/logs/refs/remotes/origin/
# comm_exercise/.git/logs/refs/remotes/origin/master
# comm_exercise/.git/logs/refs/heads/
# comm_exercise/.git/logs/refs/heads/master
# comm_exercise/publish-subscribe/
# comm_exercise/publish-subscribe/sub_client.py
# comm_exercise/publish-subscribe/pub_server.py
# comm_exercise/testpublisher.sh
# comm_exercise/.gitignore
# comm_exercise/testbroadcastreceiver.sh
# comm_exercise/testpisyncmaster.sh
# comm_exercise/rpc/
# comm_exercise/rpc/rpc_sync_pi_master.py
# comm_exercise/rpc/rpc_sync_pi_slave.py
# comm_exercise/rpc/rpc_sync_master.py
# comm_exercise/rpc/__pycache__/
# comm_exercise/rpc/__pycache__/util.cpython-36.pyc
# comm_exercise/rpc/rpc_sync_slave.py
# comm_exercise/rpc/util.py
# comm_exercise/rpc/rpc_async_pi_master.py
# comm_exercise/rpc/aioxmlrpc/
# comm_exercise/rpc/aioxmlrpc/client.py
# comm_exercise/testsubscriber.sh
# comm_exercise/dependencies.txt
# comm_exercise/testpislave.sh

# %%
import json

nodes = {'1': {'id':1, #both should be the same and unique (also used for leader election)
               'ip':'192.168.0.101',
               'rpc_port': 9001,
               'rpc_status':1, #1=master, 0=slave
               'produce':1, #1=yes, 0=no
               'control':1, #1=yes, 0=no
               'publish_ports':{'keep_alive':5001,
                                'measurement':6001
                               }
               #'subscribed_ports':{} #it will fill in when adding to the system
              },
         
         '10': {'id':10, #both should be the same and unique (also used for leader election)
               'ip':'192.168.0.110',
               'rpc_port': 9010,
               'rpc_status':10, #1=master, 0=slave
               'produce':10, #1=yes, 0=no
               'control':10, #1=yes, 0=no
               'publish_ports':{'keep_alive':5010,
                                'measurement':6010
                               }
               #'subscribed_ports':{} #it will fill in when adding to the system
              }
        }


print('nodes type = {}'.format(type(nodes)))
j1 = json.dumps(nodes, ensure_ascii=False)
print('j1 type = {}'.format(type(j1)))
d1 = json.loads(j1)
print('d1 type = {}'.format(type(d1)))

print('\n---\n')
print(j1)
print('__')
if nodes == d1:
    print(d1)
else:
    print('caca')
# Out:
# nodes type = <class 'dict'>
# j1 type = <class 'str'>
# d1 type = <class 'dict'>
#
# ---
#
# {"1": {"id": 1, "ip": "192.168.0.101", "rpc_port": 9001, "rpc_status": 1, "produce": 1, "control": 1, "publish_ports": {"keep_alive": 5001, "measurement": 6001}}, "10": {"id": 10, "ip": "192.168.0.110", "rpc_port": 9010, "rpc_status": 10, "produce": 10, "control": 10, "publish_ports": {"keep_alive": 5010, "measurement": 6010}}}
# __
# {'1': {'id': 1, 'ip': '192.168.0.101', 'rpc_port': 9001, 'rpc_status': 1, 'produce': 1, 'control': 1, 'publish_ports': {'keep_alive': 5001, 'measurement': 6001}}, '10': {'id': 10, 'ip': '192.168.0.110', 'rpc_port': 9010, 'rpc_status': 10, 'produce': 10, 'control': 10, 'publish_ports': {'keep_alive': 5010, 'measurement': 6010}}}

# %%
# !wget --no-parent http://bit.ly/CEEDistContLeaderElection
# !tar -xvf CEEDistContLeaderElection
# Out:
# --2018-06-19 09:46:41--  http://bit.ly/CEEDistContLeaderElection
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://178.62.224.64/~tue/leader_election.tar [following]
# --2018-06-19 09:46:41--  http://178.62.224.64/~tue/leader_election.tar
# Connecting to 178.62.224.64:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10240 (10K) [application/x-tar]
# Saving to: ‘CEEDistContLeaderElection’
#
# CEEDistContLeaderEl 100%[===================>]  10.00K  --.-KB/s    in 0s
#
# 2018-06-19 09:46:41 (151 MB/s) - ‘CEEDistContLeaderElection’ saved [10240/10240]
#
# leader_election/
# leader_election/leader_election_test.ipynb
# leader_election/Leader_election.ipynb
